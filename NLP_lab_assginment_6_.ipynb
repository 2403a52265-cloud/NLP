# %% [markdown]
# <a href="https://colab.research.google.com/github/2403a52265-cloud/NLP/blob/main/NLP_lab_assginment_6_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LDA Using sample dataset and kaggle dataset

# %%
import pandas as pd
data = pd.read_excel("/content/LDA-Data.xlsx")
data_1 = pd.read_csv("/content/arxiv_data.csv")
display(data_1.head())
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipython-input-3654513172.py in <cell line: 0>()
#       1 import pandas as pd
#       2 data = pd.read_excel("/content/LDA-Data.xlsx")
# ----> 3 data_1 = pd.read_csv("/content/arxiv_data.csv")
#       4 display(data_1.head())
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     624
#     625     with parser:
# --> 626         return parser.read(nrows)
#     627
#     628
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1921                     columns,
#    1922                     col_dict,
# -> 1923                 ) = self._engine.read(  # type: ignore[attr-defined]
#    1924                     nrows
#    1925                 )
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     232         try:
#     233             if self.low_memory:
# --> 234                 chunks = self._reader.read_low_memory(nrows)
#     235                 # destructive to chunks
#     236                 data = _concatenate_chunks(chunks)
#
# parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# parsers.pyx in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: EOF inside string starting at row 23974

# %%
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')

def nltk_preprocessing_pipeline(text):

    lemmatizer = WordNetLemmatizer()
    stop_words = set(stopwords.words('english'))


    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)

    text = re.sub(r'<.*?>', '', text)

    text = re.sub(r'@\w+', '', text)

    text = re.sub(r'#\w+', '', text)

    text = text.lower()

    emoji_pattern = re.compile(
        "["
        "\U0001F600-\U0001F64F"
        "\U0001F300-\U0001F5FF"
        "\U0001F680-\U0001F6FF"
        "\U0001F1E0-\U0001F1FF"
        "\U00002702-\U000027B0"
        "\U000024C2-\U0001F251"
        "]+", flags=re.UNICODE
    )
    text = emoji_pattern.sub(r'', text)

    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()


    tokenized_words = word_tokenize(text)

    filtered_words = [word for word in tokenized_words if word not in stop_words]

    lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]

    clean_summary = ' '.join(lemmatized_words)

    return clean_summary

print("NLTK preprocessing pipeline function created successfully!")

# %%
data_1['clean_News'] = data_1['titles'].apply(nltk_preprocessing_pipeline)
print("\nClean summaries for data_1 (first 5 rows):")
print(data_1[['clean_News']].head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1235481894.py in <cell line: 0>()
# ----> 1 data_1['clean_News'] = data_1['titles'].apply(nltk_preprocessing_pipeline)
#       2 print("\nClean summaries for data_1 (first 5 rows):")
#       3 print(data_1[['clean_News']].head())
#
# NameError: name 'data_1' is not defined

# %%
from sklearn.feature_extraction.text import CountVectorizer

count_vectorizer_data_1 = CountVectorizer(max_df=0.95, min_df=1, stop_words='english')
doc_term_matrix_1 = count_vectorizer_data_1.fit_transform(data_1['clean_News'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3005560124.py in <cell line: 0>()
#       2
#       3 count_vectorizer_data_1 = CountVectorizer(max_df=0.95, min_df=1, stop_words='english')
# ----> 4 doc_term_matrix_1 = count_vectorizer_data_1.fit_transform(data_1['clean_News'])
#
# NameError: name 'data_1' is not defined

# %%
import pandas as pd

feature_names_1 = count_vectorizer_data_1.get_feature_names_out()
bow_df_1 = pd.DataFrame(doc_term_matrix_1.toarray(),columns=feature_names_1)
bow_top_10_1 = bow_df_1.head(10)
print(bow_top_10_1)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /tmp/ipython-input-2960971942.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 feature_names_1 = count_vectorizer_data_1.get_feature_names_out()
#       4 bow_df_1 = pd.DataFrame(doc_term_matrix_1.toarray(),columns=feature_names_1)
#       5 bow_top_10_1 = bow_df_1.head(10)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/feature_extraction/text.py in get_feature_names_out(self, input_features)
#    1470             Transformed feature names.
#    1471         """
# -> 1472         self._check_vocabulary()
#    1473         return np.asarray(
#    1474             [t for t, i in sorted(self.vocabulary_.items(), key=itemgetter(1))],
#
# /usr/local/lib/python3.12/dist-packages/sklearn/feature_extraction/text.py in _check_vocabulary(self)
#     499             self._validate_vocabulary()
#     500             if not self.fixed_vocabulary_:
# --> 501                 raise NotFittedError("Vocabulary not fitted or provided")
#     502
#     503         if len(self.vocabulary_) == 0:
#
# NotFittedError: Vocabulary not fitted or provided

# %%
from sklearn.decomposition import LatentDirichletAllocation


num_topics = 2
LDA_data_1 = LatentDirichletAllocation(n_components=num_topics, random_state=42)
LDA_data_1.fit(doc_term_matrix_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3005240475.py in <cell line: 0>()
#       4 num_topics = 2
#       5 LDA_data_1 = LatentDirichletAllocation(n_components=num_topics, random_state=42)
# ----> 6 LDA_data_1.fit(doc_term_matrix_1)
#
# NameError: name 'doc_term_matrix_1' is not defined

# %%
def display_topics(model, feature_names, num_top_words):
    for topic_idx in range(len(model.components_)):
        print(f"\nTopic {topic_idx}:")


        topic_weights = model.components_[topic_idx]


        sorted_indices = topic_weights.argsort()[::-1]


        top_indices = sorted_indices[:num_top_words]

        for idx in top_indices:
            print(feature_names[idx], end=" ")
        print()

# %%
num_top_words = 10
print(f"\nTop {num_top_words} words per topic from data_1:")
display_topics(LDA_data_1, count_vectorizer_data_1.get_feature_names_out(), num_top_words)
# Out:
# Top 10 words per topic from data_1:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3006555870.py in <cell line: 0>()
#       1 num_top_words = 10
#       2 print(f"\nTop {num_top_words} words per topic from data_1:")
# ----> 3 display_topics(LDA_data_1, count_vectorizer_data_1.get_feature_names_out(), num_top_words)
#
# NameError: name 'display_topics' is not defined

# %%
document_topics_1 = LDA_data_1.transform(doc_term_matrix_1)
data_1['topic'] = document_topics_1.argmax(axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2520092792.py in <cell line: 0>()
# ----> 1 document_topics_1 = LDA_data_1.transform(doc_term_matrix_1)
#       2 data_1['topic'] = document_topics_1.argmax(axis=1)
#
# NameError: name 'doc_term_matrix_1' is not defined

# %% [markdown]
# # LDA output with sample data

# %%
print("\nDataFrame with assigned topics for data_1 (first 5 rows):")
print(data_1[['clean_News', 'topic']].head())
# Out:
# DataFrame with assigned topics for data_1 (first 5 rows):
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-903063701.py in <cell line: 0>()
#       1 print("\nDataFrame with assigned topics for data_1 (first 5 rows):")
# ----> 2 print(data_1[['clean_News', 'topic']].head())
#
# NameError: name 'data_1' is not defined

# %% [markdown]
# # LDA output with kaggle dataset

# %%
print("\nDataFrame with assigned topics (first 5 rows):")
print(data_1[['clean_News', 'topic']].head())

# %% [markdown]
# # NMF Using sample dataset and kaggle dataset

# %%
from sklearn.decomposition import NMF


num_topics = 2
NMF_data_1 = NMF(n_components=num_topics, random_state=42)
NMF_data_1.fit(doc_term_matrix_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3536264673.py in <cell line: 0>()
#       4 num_topics = 2
#       5 NMF_data_1 = NMF(n_components=num_topics, random_state=42)
# ----> 6 NMF_data_1.fit(doc_term_matrix_1)
#
# NameError: name 'doc_term_matrix_1' is not defined

# %%
def display_topics(model, feature_names, num_top_words):
    for topic_idx in range(len(model.components_)):
        print(f"\nTopic {topic_idx}:")


        topic_weights = model.components_[topic_idx]


        sorted_indices = topic_weights.argsort()[::-1]


        top_indices = sorted_indices[:num_top_words]

        for idx in top_indices:
            print(feature_names[idx], end=" ")
        print()

# %%
num_top_words = 10
print(f"\nTop {num_top_words} words per topic from data_1:")
display_topics(NMF_data_1, count_vectorizer_data_1.get_feature_names_out(), num_top_words)
# Out:
# Top 10 words per topic from data_1:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2384605300.py in <cell line: 0>()
#       1 num_top_words = 10
#       2 print(f"\nTop {num_top_words} words per topic from data_1:")
# ----> 3 display_topics(NMF_data_1, count_vectorizer_data_1.get_feature_names_out(), num_top_words)
#
# NameError: name 'display_topics' is not defined

# %%
document_topics_1 = NMF_data_1.transform(doc_term_matrix_1)
data_1['topic'] = document_topics_1.argmax(axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2725220747.py in <cell line: 0>()
# ----> 1 document_topics_1 = NMF_data_1.transform(doc_term_matrix_1)
#       2 data_1['topic'] = document_topics_1.argmax(axis=1)
#
# NameError: name 'doc_term_matrix_1' is not defined

# %% [markdown]
# # NMF OUTPUT WITH SAMPLEDATA

# %%
print("\nDataFrame with assigned topics for data_1 (first 5 rows):")
print(data_1[['clean_News', 'topic']].head())
# Out:
# DataFrame with assigned topics for data_1 (first 5 rows):
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-903063701.py in <cell line: 0>()
#       1 print("\nDataFrame with assigned topics for data_1 (first 5 rows):")
# ----> 2 print(data_1[['clean_News', 'topic']].head())
#
# NameError: name 'data_1' is not defined

# %% [markdown]
# # NMF OUTPUT WITH KAGGLE DATASET

# %%
print("\nDataFrame with assigned topics (first 5 rows):")
print(data_1[['clean_News', 'topic']].head())

# %% [markdown]
# # NMF Using TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer_data_1 = TfidfVectorizer(max_df=0.95, min_df=1, stop_words='english')
tfidf_matrix_1 = tfidf_vectorizer_data_1.fit_transform(data_1['clean_News'])

print("Shape of TF-IDF matrix for data_1:", tfidf_matrix_1.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-17800310.py in <cell line: 0>()
#       2
#       3 tfidf_vectorizer_data_1 = TfidfVectorizer(max_df=0.95, min_df=1, stop_words='english')
# ----> 4 tfidf_matrix_1 = tfidf_vectorizer_data_1.fit_transform(data_1['clean_News'])
#       5
#       6 print("Shape of TF-IDF matrix for data_1:", tfidf_matrix_1.shape)
#
# NameError: name 'data_1' is not defined

# %%
from sklearn.decomposition import NMF

num_topics = 2

NMF_tfidf_data_1 = NMF(n_components=num_topics, random_state=42)
NMF_tfidf_data_1.fit(tfidf_matrix_1)

print('NMF model fitted using TF-IDF for data_1 dataset.')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1984820847.py in <cell line: 0>()
#       4
#       5 NMF_tfidf_data_1 = NMF(n_components=num_topics, random_state=42)
# ----> 6 NMF_tfidf_data_1.fit(tfidf_matrix_1)
#       7
#       8 print('NMF model fitted using TF-IDF for data_1 dataset.')
#
# NameError: name 'tfidf_matrix_1' is not defined

# %% [markdown]
# # *NMF output using tf-idf for sample data*

# %%
num_top_words = 10
print(f"\nTop {num_top_words} words per topic from data_1 (TF-IDF NMF):")
display_topics(NMF_tfidf_data_1, tfidf_vectorizer_data_1.get_feature_names_out(), num_top_words)
# Out:
# Top 10 words per topic from data_1 (TF-IDF NMF):
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4167198776.py in <cell line: 0>()
#       1 num_top_words = 10
#       2 print(f"\nTop {num_top_words} words per topic from data_1 (TF-IDF NMF):")
# ----> 3 display_topics(NMF_tfidf_data_1, tfidf_vectorizer_data_1.get_feature_names_out(), num_top_words)
#
# NameError: name 'display_topics' is not defined

# %%
print(data_1[['clean_News', 'topic']].head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2334859761.py in <cell line: 0>()
# ----> 1 print(data_1[['clean_News', 'topic']].head())
#
# NameError: name 'data_1' is not defined

# %% [markdown]
# # NMF output using tf-idf for kaggle data

# %%
num_top_words = 10
print(f"\nTop {num_top_words} words per topic from data_1 (TF-IDF NMF):")
display_topics(NMF_tfidf_data_1, tfidf_vectorizer_data_1.get_feature_names_out(), num_top_words)

# %%
print(data_1[['clean_News', 'topic']].head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2334859761.py in <cell line: 0>()
# ----> 1 print(data_1[['clean_News', 'topic']].head())
#
# NameError: name 'data_1' is not defined
